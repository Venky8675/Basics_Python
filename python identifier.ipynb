# %% [markdown]
# ![image.png](attachment:22b6cfa7-7d31-40e4-84e4-fa6aa62e79a2.png)
#
# youtu.be/PhIAQ8rE2xc?si=w6KcKpEuVc7Yf24- (software installation link)

# %% [markdown]
# # 19th sep

# %%
'WELCOME TO NARESHIT'
# Out:
# 'WELCOME TO NARESHIT'

# %%
"WELCOME TO NARESHIT1"
# Out:
# 'WELCOME TO NARESHIT1'

# %%
''' WELCOME TO NARESHIT1 "
# Out:
#   Cell In[3], line 1
#     ''' WELCOME TO NARESHIT1 "
#     ^
# SyntaxError: incomplete input

# %%
''' WELCOME TO NARESHIT1 '''
# Out:
# ' WELCOME TO NARESHIT1 '

# %%
''' WELCOME TO 

NARESHIT1 '''
# Out:
# ' WELCOME TO \n\nNARESHIT1 '

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5 # FLOAT DIVISION
# Out:
# 2.0

# %%
10 // 5 #INT DIVISION
# Out:
# 2

# %%
10
# Out:
# 10

# %%
(3+4+5)+3-4
# Out:
# 11

# %%
s = 'welcome'
s
# Out:
# 'welcome'

# %% [markdown]
# # 20th Sep

# %%
a = 10

# %%
id(a)
# Out:
# 140726080619592

# %%
a = 20

# %%
a = 20
a
# Out:
# 20

# %%
id(a)
# Out:
# 140726080619912

# %%
a = 10
b = 20

# %%
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(id(a))
print(id(b))
# Out:
# 140726080619592
# 140726080619912

# %% [markdown]
# # python identifer = variable = object

# %%
nit = 15
Nit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 nit = 15
# ----> 2 Nit
#
# NameError: name 'Nit' is not defined

# %%
nit
# Out:
# 15

# %%
id(nit)
# Out:
# 140726080619752

# %%
1nit = 15
1nit
# Out:
#   Cell In[16], line 1
#     1nit = 15
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 15
nit1
# Out:
# 15

# %%
nit$ = 78
# Out:
#   Cell In[21], line 1
#     nit$ = 78
#        ^
# SyntaxError: invalid syntax

# %%
nit_ = 78
nit_
# Out:
# 78

# %%
_nit = 5
_nit
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
pass = 78
# Out:
#   Cell In[28], line 1
#     pass = 78
#          ^
# SyntaxError: invalid syntax

# %%
True = 90
# Out:
#   Cell In[29], line 1
#     True = 90
#     ^
# SyntaxError: cannot assign to True

# %%
TRUE = 90
TRUE
# Out:
# 90

# %%
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa = 9
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa
# Out:
# 9

# %% [markdown]
# # python identifier is completed

# %% [raw]
# - variable is case sensitive
# - cannot start with digit
# - keywords neve be an identiifer (35 | 36 keywords) | True, False, None -- start with capital letter
# - no special character is allowed
# - no lenth limit
